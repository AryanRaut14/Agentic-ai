# %% [markdown]
# ### MESSAGES
#
# They represent input and output of models, carrying role, metadata and content to represent state of convo when interacting with an LLM.
# Role : Identifies msg type (user, ai, system)
# Content : Actual content of message
# Metadata : optional fields such as info, msg ids and token usage

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("Please tell what is AI")
#input goes as an user message
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "Please tell what is AI". This is a straightforward, foundational question about Artificial Intelligence.\n\n2.  **Identify Key Components of AI Definition**:\n   - What does AI stand for? (Artificial Intelligence)\n   - Core concept: Machines/computer systems performing tasks that typically require human intelligence\n   - Key capabilities: Learning, reasoning, problem-solving, perception, language understanding, decision-making\n   - Types/Categories: Narrow/Weak AI vs. General/Strong AI (and sometimes Super AI, though theoretical)\n   - How it works: Algorithms, data, machine learning, deep learning, neural networks\n   - Applications: Everyday examples (voice assistants, recommendations, self-driving cars, medical diagnosis, etc.)\n   - Current state: Mostly narrow AI, rapidly advancing\n   - Important context: AI is a field of computer science, not sentient or conscious\n\n3.  **Structure the Response**:\n   - Clear, concise definition first\n   - Break down key aspects (what it does, how it works, types)\n   - Give relatable examples\n   - Clarify common misconceptions\n   - Keep it accessible but accurate\n   - Offer to dive deeper if needed\n\n4.  **Draft the Response (Mental Refinement)**:\n   Artificial Intelligence (AI) is a branch of computer science focused on creating systems that can perform tasks that normally require human intelligence. These tasks include understanding language, recognizing patterns, solving problems, making decisions, and learning from experience.\n\n   AI isn’t a single technology but a broad field that includes:\n   - **Machine Learning**: Systems that improve automatically through experience and data\n   - **Deep Learning**: A subset using artificial neural networks inspired by the human brain\n   - **Natural Language Processing**: Understanding and generating human language\n   - **Computer Vision**: Interpreting visual information from images or video\n\n   Most AI today is **Narrow AI** – designed for specific tasks (like recommending videos, filtering spam, or powering voice assistants). **General AI** (human-level, flexible intelligence) remains theoretical and doesn’t exist yet.\n\n   AI works by finding patterns in large amounts of data using mathematical models and algorithms. It doesn’t “think” or “understand” like humans do – it processes information statistically and follows programmed objectives.\n\n   Examples in daily life: smartphone keyboards predicting words, navigation apps routing traffic, medical imaging analysis, customer service chatbots, and generative AI that creates text, images, or code.\n\n   If you’d like, I can explain how a specific type of AI works, its real-world applications, or address common questions about safety and limitations!\n\n5.  **Self-Correction/Verification**:\n   - Accurate? Yes, aligns with current scientific/technical consensus\n   - Clear for general audience? Yes, avoids unnecessary jargon, explains terms\n   - Covers essentials? Definition, how it works, types, examples, limitations\n   - Avoids overclaiming? Explicitly states AI doesn\'t "think" like humans, clarifies narrow vs general AI\n   - Tone appropriate? Informative, helpful, open to follow-up\n   - Length? Concise but comprehensive\n\n   All good. Ready to output. All points align with standard AI definitions from reputable sources (IEEE, ACM, academic consensus). No speculation, clear boundaries between current capabilities and theoretical concepts. Includes practical context. Offers further assistance.✅\n</think>\n\n**Artificial Intelligence (AI)** is a field of computer science focused on building systems that can perform tasks that typically require human intelligence. These tasks include:\n- Understanding and generating human language\n- Recognizing patterns in data (images, sound, text, etc.)\n- Learning from experience\n- Solving problems and making decisions\n- Adap ...

# %% [markdown]
# Text Prompts
#
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %% [markdown]
# Use text prompts when:
#
#     You have a single, standalone request
#     You don’t need conversation history
#     You want minimal code complexity

# %% [markdown]
# Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types
#
#     System message - Tells the model how to behave and provide context for interactions
#     Human message - Represents user input and interactions with the model
#     AI message - Responses generated by the model, including text content, tool calls, and metadata
#     Tool message - Represents the outputs of tool calls
#
# System Message
#
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
# Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
# AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
# Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query**: The user asks "How do I create a REST API?" This is a broad question, so I need to provide a clear, structured, and practical answer. Since I'm a senior Python developer with web framework expertise, I should focus on Python-based solutions, specifically popular frameworks like FastAPI and Flask, with FastAPI being the modern recommendation.
#
# 2.  **Identify Key Components of a REST API**:
#    - Route definitions (endpoints)
#    - HTTP methods (GET, POST, PUT, DELETE)
#    - Request/response handling
#    - Data validation/serialization
#    - Error handling
#    - Framework choice
#    - Deployment considerations (briefly)
#
# 3.  **Choose the Best Framework for the Example**:
#    - FastAPI is modern, fast, auto-generates docs, has built-in validation, and is highly recommended for new projects.
#    - Flask is good but more manual. I'll stick with FastAPI as the primary example, but mention alternatives briefly.
#
# 4.  **Structure the Response**:
#    - Brief introduction to REST API concepts
#    - Framework recommendation (FastAPI)
#    - Step-by-step code example
#    - Explanation of key parts
#    - Next steps/best practices
#    - Keep it concise but thorough
#
# 5.  **Draft the Code Example (Mental Refinement)**:
#    ```python
#    from fastapi import FastAPI, HTTPException
#    from pydantic import BaseModel
#
#    app = FastAPI()
#
#    # Data model
#    class Item(BaseModel):
#        name: str
#        price: float
#        is_offer: bool = False
#
#    # In-memory "database"
#    items_db = {}
#
#    # GET all items
#    @app.get("/items/")
#    def read_items():
#        return items_db
#
#    # GET single item
#    @app.get("/items/{item_id}")
#    def read_item(item_id: str):
#        if item_id not in items_db:
#            raise HTTPException(status_code=404, detail="Item not found")
#        return items_db[item_id]
#
#    # POST create item
#    @app.post("/items/", status_code=201)
#    def create_item(item: Item):
#        items_db[item.name] = item
#        return item
#
#    # PUT update item
#    @app.put("/items/{item_id}")
#    def update_item(item_id: str, item: Item):
#        if item_id not in items_db:
#            raise HTTPException(status_code=404, detail="Item not found")
#        items_db[item_id] = item
#        return item
#
#    # DELETE item
#    @app.delete("/items/{item_id}", status_code=204)
#    def delete_item(item_id: str):
#        if item_id not in items_db:
#            raise HTTPException(status_code=404, detail="Item not found")
#        del items_db[item_id]
#        return None
#    ```
#
# 6.  **Explain Key Concepts**:
#    - FastAPI setup
#    - Pydantic models for validation
#    - Route decorators mapping HTTP methods
#    - Path/query parameters
#    - Status codes
#    - Error handling with HTTPException
#    - Auto-generated docs (Swagger/ReDoc)
#
# 7.  **Add Best Practices & Next Steps**:
#    - Use async/await where appropriate
#    - Database integration (SQLAlchemy, asyncpg)
#    - Authentication/authorization (OAuth2, JWT)
#    - Testing (pytest, TestClient)
#    - Deployment (Uvicorn, Gunicorn, Docker)
#    - Keep it concise
#
# 8.  **Self-Correction/Refinement during drafting**:
#    - The example uses `item.name` as a key, which might not be ideal. Better to use a separate ID field or auto-generated ID. Let's adjust to use `item_id` as the key and add an `id` field to the model, or keep it simple but note it's a demo.
#    - Actually, for simplicity, I'll keep it as-is but add a note that production apps use databases and proper ID generation.
#    - I should mention how to run it: `uvicorn main:app --reload`
#    - Make sure to explain REST principles briefly (stateless, resource-based, standard HTTP methods, status codes)
#    - Keep explanations tight.
#
#    Revised structure:
#    - Quick REST principles
#    - Why FastAPI
#    - Complete runnable example
#    - How to run it
#    - Key concepts explained
#    - Production-ready next steps
#    - All concise.
#
# 9.  **Final Output Generation**: (matches the refined version)
#    - Start with framework choice
#    - Provide code
#    - Explain architecture/components
#    - Give run instructions
#    - List best practices
#    - Keep tone professional, senior-level, Python-focused.✅
# </think>
#
# Here’s a production-minded, minimal example using **FastAPI**, the modern Python standard for REST APIs. It includes routing, validation, error handling, and auto-generated documentation.
#
# ### 1. Install Dependencies
# ```bash
# pip install fastapi uvicorn pydantic
# ```
#
# ### 2. Create `main.py`
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
#
# app = FastAPI(title="Item API", version="1.0.0")
#
# # Data validation & serialization model
# class Item(BaseModel):
#     name: str
#     price: float
#     in_stock: bool = True
#
# # In-memory store (replace with a DB in production)
# items_db: dict[str, Item] = {}
#
# # GET all items
# @app.get("/items/")
# def list_items():
#     return list(items_db.values())
#
# # GET single item
# @app.get("/items/{item_id}")
# def get_item(item_id: str):
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     return items_db[item_id]
#
# # POST create item
# @app.post("/items/", status_code=201)
# def create_item(item: Item):
#     items_db[item.name] = item
#     return item
#
# # PUT update item
# @app.put("/items/{item_id}")
# def update_item(item_id: str, item: Item):
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     items_db[item_id] = item
#     return item
#
# # DELETE item
# @app.delete("/items/{item_id}", status_code=204)
# def delete_item(item_id: str):
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     del items_db[item_id]
#     return None
# ```
#
# ### 3. Run the Server
# ```bash
# uvicorn main:app --reload
# ```
# - Open `http://localhost:8000/docs` → Swagger UI (auto-generated)
# - Open `http://localhost:8000/redoc` → ReDoc alternative
#
# ---
#
# ### 🔑 Key Concepts Explained
# | Concept | Why It Matters |
# |--------|----------------|
# | `@app.get/post/put/delete` | Maps HTTP verbs to Python functions. REST is verb-driven. |
# | `Pydantic BaseModel` | Validates incoming JSON, enforces types, and auto-generates OpenAPI schema. |
# | `HTTPException` | Standardized error handling. FastAPI converts it to proper HTTP status + JSON body. |
# | `status_code=201/204` | Explicit status codes follow REST conventions (201 = created, 204 = no content). |
# | Path parameters `{item_id}` | Extracted automatically and type-checked. |
#
# ---
#
# ### 🚀 Production Next Steps
# 1. **Database**: Replace `items_db` with SQLAlchemy + asyncpg/psycopg or an ORM like SQLModel.
# 2. **Async Support**: Change `def` to `async def` for I/O-bound operations (DB, HTTP calls).
# 3. **Auth**: Add OAuth2/JWT via `fastapi.security` or libraries like `authlib`.
# 4. **Testing**: Use `fastapi.testclient.TestClient` with `pytest`.
# 5. **Deployment**: Run with `gunicorn + uvicorn` workers, containerize with Docker, and reverse-proxy via Nginx/Traefik.
#
# ### Why FastAPI over Flask/Django?
# - **Performance**: Built on Starlette + Pydantic, comparable to Node.js/Go.
# - **Developer Experience**: Type hints → auto docs, validation, and IDE support.
# - **Modern Defaults**: Async-native, dependency injection, and OpenAPI-first.
#
# Need a specific feature (pagination, file uploads, database integration, or auth)? Tell me your stack and I’ll give you a tailored snippet.

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response = model.invoke([
  human_msg
])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "Hello!"\n   - This is a simple greeting.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - No specific question or request is made.\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting warmly.\n   - Keep it open-ended to encourage further interaction.\n   - Maintain a friendly, helpful tone.\n   - Offer assistance.\n\n4.  **Draft Response (Mental):**\n   - "Hello! How can I assist you today?"\n   - "Hi there! What\'s on your mind?"\n   - "Hello! I\'m here to help. What can I do for you?"\n\n5.  **Refine Response:**\n   - Keep it concise and natural.\n   - "Hello! How can I help you today?" is standard, friendly, and effective.\n\n6.  **Final Output Generation:** (matches the refined version)\n   - "Hello! How can I assist you today?" ✅\n\n   All steps check out. No complex reasoning needed. Ready to respond.✅\n</think>\n\nHello! How can I assist you today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 267, 'prompt_tokens': 12, 'total_tokens': 279, 'completion_time': 0.509353893, 'completion_tokens_details': None, 'prompt_time': 0.000662606, 'prompt_tokens_details': None, 'queue_time': 0.053373783, 'total_time': 0.510016499}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_2f860a3fc2', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fa7b7-23de-7381-9283-58c4dfbbdfc5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 267, 'total_tokens': 279})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user asks "Great! What's 2+2?"
# 2.  **Identify Core Question:** It's a simple arithmetic question: 2 + 2.
# 3.  **Calculate/Verify:** 2 + 2 = 4. This is a basic mathematical fact.
# 4.  **Formulate Response:** Keep it clear, direct, and friendly. "2 + 2 equals 4." or "The answer is 4."
# 5.  **Check for Nuance/Traps:** None. It's straightforward.
# 6.  **Output Generation:** Provide the answer concisely. "2 + 2 equals 4. Let me know if you need help with anything else!" (Keep it helpful and open-ended).✅
# </think>
#
# 2 + 2 equals **4**. Let me know if you have any other questions!
